# %%
import pandas as pd
from sklearn.model_selection import train_test_split

csv_path = "ILDC_multi/ILDC_multi.csv"

# Load the CSV file, including the 'split' column
dtype = {'text': str, 'label': int, 'split': str}
df = pd.read_csv(csv_path, usecols=['text', 'label', 'split', 'name'], low_memory=False, dtype=dtype)
6
# Use only a random subset (e.g., 1000 rows)
df = df.sample(n=400, random_state=42)

# Filter for the train split
train_df = df[df['split'] == 'train']
test_df = df[df['split'] == 'test']


# Split train_df into train and dev (e.g., 80% train, 20% dev)
train_split_df, dev_split_df = train_test_split(
    train_df,
    test_size=0.2,      # 20% for dev
    random_state=42,    # for reproducibility
    stratify=train_df['label']  # stratify to keep label distribution
)

# Extract texts and labels for training
train_texts = train_split_df['text'].tolist()
train_labels = train_split_df['label'].tolist()
train_labels = torch.tensor(train_labels, dtype=torch.long)

# Extract texts and labels for dev
dev_texts = dev_split_df['text'].tolist()
dev_labels = dev_split_df['label'].tolist()
dev_labels = torch.tensor(dev_labels, dtype=torch.long)

# Extract texts and labels for testing
test_texts = test_df['text'].tolist()
test_labels = test_df['label'].tolist()
test_labels = torch.tensor(test_labels, dtype=torch.long)

# %%
from transformers import AutoTokenizer, AutoModel
import torch

# Load InLegalBERT tokenizer and model
tokenizer = AutoTokenizer.from_pretrained("law-ai/InLegalBERT")
model = AutoModel.from_pretrained("law-ai/InLegalBERT")
model.eval()  # Set to evaluation mode

print("loading done")
# Out:
# loading done

# %%
def chunk(text, max_length=512, stride=256):
    """
    Split a long document into chunks of max_length tokens using InLegalBERT tokenizer with overlap.
    Args:
        text: Input text to be chunked.
        max_length: Maximum number of tokens per chunk.
        stride: Number of tokens to overlap between chunks.
    Returns:
        List of token ID lists, each representing a chunk.
    """
    tokens = tokenizer.encode(text, add_special_tokens=True)
    chunks = []
    for i in range(0, len(tokens), max_length - stride):
        chunk = tokens[i: i + max_length]
        chunks.append(chunk)
    return chunks

# %%
def get_vector(text):
    """
    Generate [CLS] embeddings for each chunk of the input text using InLegalBERT.
    Args:
        text: Input text to generate embeddings for.
    Returns:
        Tensor of shape (num_chunks, 768) containing [CLS] embeddings for each chunk.
    """
    chunks = chunk(text)
    cls_vectors = []

    for chunk_ids in chunks:
        print(f"chunk_ids length: {len(chunk_ids)}")
        input_ids = torch.tensor([chunk_ids])  # shape: [1, seq_len]
        attention_mask = torch.ones_like(input_ids)  # shape: [1, seq_len]

        inputs = {
            "input_ids": input_ids,
            "attention_mask": attention_mask
        }

        with torch.no_grad():
            outputs = model(**inputs)
            cls_vector = outputs.last_hidden_state[:, 0, :]  # shape: [1, 768]
            cls_vectors.append(cls_vector.squeeze(0))  # shape: [768]

    # Stack all [CLS] vectors into a single tensor
    doc_tensor = torch.stack(cls_vectors)  # shape: [num_chunks, 768]
    print("Document tensor shape:", doc_tensor.shape)
    return doc_tensor

# %%
train_vectors = []
for item in train_texts:
    doc_tensor = get_vector(item)        # shape = [num_chunks, 768]
    pooled     = doc_tensor.mean(0)      # shape = [768]  ← NEW
    train_vectors.append(pooled)

# Stack vectors: shape (num_docs, num_chunks, 768)
X_train = torch.stack(train_vectors)  # shape: [4, num_chunks, 768]

# Save to workspace
file_path = "data_train.pt"
torch.save({'X': X_train, 'y': train_labels}, file_path)
print("Saved training data:", file_path)


test_vectors = []
for item in test_texts:
    doc_tensor = get_vector(item)        # shape = [num_chunks, 768]
    pooled     = doc_tensor.mean(0)      # shape = [768]  ← NEW
    test_vectors.append(pooled)

# Stack vectors: shape (num_docs, num_chunks, 768)
X_test = torch.stack(test_vectors)  # shape: [3, num_chunks, 768]

# Save to workspace
file_path = "data_test.pt"
torch.save({'X': X_train, 'y': train_labels}, file_path)
print("Saved testing data:", file_path)

dev_vectors = []
for item in dev_texts:
    doc_tensor = get_vector(item)        # shape = [num_chunks, 768]
    pooled     = doc_tensor.mean(0)      # shape = [768]  ← NEW
    dev_vectors.append(pooled)

# Stack vectors: shape (num_docs, num_chunks, 768)
X_dev = torch.stack(dev_vectors)  # shape: [3, num_chunks, 768]

# Save to workspace
file_path = "data_dev.pt"
torch.save({'X': X_dev, 'y': dev_labels}, file_path)
print("Saved dev data:", file_path)
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (4142 > 512). Running this sequence through the model will result in indexing errors
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 302
# chunk_ids length: 46
# Document tensor shape: torch.Size([17, 768])
# chunk_ids length: 312
# chunk_ids length: 56
# Document tensor shape: torch.Size([2, 768])
# chunk_ids length: 317
# chunk_ids length: 61
# Document tensor shape: torch.Size([2, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 333
# chunk_ids length: 77
# Document tensor shape: torch.Size([17, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 441
# chunk_ids length: 185
# Document tensor shape: torch.Size([17, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 503
# chunk_ids length: 247
# Document tensor shape: torch.Size([34, 768])
# chunk_ids length: 512
# chunk_ids length: 429
# chunk_ids length: 173
# Document tensor shape: torch.Size([3, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 304
# chunk_ids length: 48
# Document tensor shape: torch.Size([15, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 494
# chunk_ids length: 238
# Document tensor shape: torch.Size([20, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 471
# chunk_ids length: 215
# Document tensor shape: torch.Size([23, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 260
# chunk_ids length: 4
# Document tensor shape: torch.Size([10, 768])
# chunk_ids length: 512
# chunk_ids length: 487
# chunk_ids length: 231
# Document tensor shape: torch.Size([3, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 418
# chunk_ids length: 162
# Document tensor shape: torch.Size([46, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 315
# chunk_ids length: 59
# Document tensor shape: torch.Size([32, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 334
# chunk_ids length: 78
# Document tensor shape: torch.Size([34, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 471
# chunk_ids length: 215
# Document tensor shape: torch.Size([8, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 272
# chunk_ids length: 16
# Document tensor shape: torch.Size([24, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 268
# chunk_ids length: 12
# Document tensor shape: torch.Size([5, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 480
# chunk_ids length: 224
# Document tensor shape: torch.Size([11, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 496
# chunk_ids length: 240
# Document tensor shape: torch.Size([5, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 349
# chunk_ids length: 93
# Document tensor shape: torch.Size([14, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 282
# chunk_ids length: 26
# Document tensor shape: torch.Size([13, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 370
# chunk_ids length: 114
# Document tensor shape: torch.Size([7, 768])
# chunk_ids length: 512
# chunk_ids length: 297
# chunk_ids length: 41
# Document tensor shape: torch.Size([3, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 475
# chunk_ids length: 219
# Document tensor shape: torch.Size([11, 768])
# chunk_ids length: 512
# chunk_ids length: 504
# chunk_ids length: 248
# Document tensor shape: torch.Size([3, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 380
# chunk_ids length: 124
# Document tensor shape: torch.Size([4, 768])
# chunk_ids length: 512
# chunk_ids length: 453
# chunk_ids length: 197
# Document tensor shape: torch.Size([3, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 403
# chunk_ids length: 147
# Document tensor shape: torch.Size([12, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 454
# chunk_ids length: 198
# Document tensor shape: torch.Size([4, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 267
# chunk_ids length: 11
# Document tensor shape: torch.Size([4, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 256
# Document tensor shape: torch.Size([19, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 476
# chunk_ids length: 220
# Document tensor shape: torch.Size([10, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 332
# chunk_ids length: 76
# Document tensor shape: torch.Size([5, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 358
# chunk_ids length: 102
# Document tensor shape: torch.Size([8, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 288
# chunk_ids length: 32
# Document tensor shape: torch.Size([14, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 470
# chunk_ids length: 214
# Document tensor shape: torch.Size([18, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 325
# chunk_ids length: 69
# Document tensor shape: torch.Size([36, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 444
# chunk_ids length: 188
# Document tensor shape: torch.Size([7, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 419
# chunk_ids length: 163
# Document tensor shape: torch.Size([15, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 288
# chunk_ids length: 32
# Document tensor shape: torch.Size([20, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 511
# chunk_ids length: 255
# Document tensor shape: torch.Size([15, 768])
# chunk_ids length: 431
# chunk_ids length: 175
# Document tensor shape: torch.Size([2, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 306
# chunk_ids length: 50
# Document tensor shape: torch.Size([55, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 380
# chunk_ids length: 124
# Document tensor shape: torch.Size([5, 768])
# chunk_ids length: 172
# Document tensor shape: torch.Size([1, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 358
# chunk_ids length: 102
# Document tensor shape: torch.Size([18, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 506
# chunk_ids length: 250
# Document tensor shape: torch.Size([11, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 464
# chunk_ids length: 208
# Document tensor shape: torch.Size([33, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 505
# chunk_ids length: 249
# Document tensor shape: torch.Size([4, 768])
# chunk_ids length: 512
# chunk_ids length: 439
# chunk_ids length: 183
# Document tensor shape: torch.Size([3, 768])
# chunk_ids length: 87
# Document tensor shape: torch.Size([1, 768])
# chunk_ids length: 512
# chunk_ids length: 373
# chunk_ids length: 117
# Document tensor shape: torch.Size([3, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 336
# chunk_ids length: 80
# Document tensor shape: torch.Size([13, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 272
# chunk_ids length: 16
# Document tensor shape: torch.Size([8, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 434
# chunk_ids length: 178
# Document tensor shape: torch.Size([6, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 472
# chunk_ids length: 216
# Document tensor shape: torch.Size([94, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 261
# chunk_ids length: 5
# Document tensor shape: torch.Size([30, 768])
# chunk_ids length: 512
# chunk_ids length: 360
# chunk_ids length: 104
# Document tensor shape: torch.Size([3, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 362
# chunk_ids length: 106
# Document tensor shape: torch.Size([5, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 315
# chunk_ids length: 59
# Document tensor shape: torch.Size([21, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 430
# chunk_ids length: 174
# Document tensor shape: torch.Size([8, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 510
# chunk_ids length: 254
# Document tensor shape: torch.Size([30, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 389
# chunk_ids length: 133
# Document tensor shape: torch.Size([30, 768])
# chunk_ids length: 352
# chunk_ids length: 96
# Document tensor shape: torch.Size([2, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 339
# chunk_ids length: 83
# Document tensor shape: torch.Size([29, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 343
# chunk_ids length: 87
# Document tensor shape: torch.Size([30, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 262
# chunk_ids length: 6
# Document tensor shape: torch.Size([11, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 392
# chunk_ids length: 136
# Document tensor shape: torch.Size([32, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 303
# chunk_ids length: 47
# Document tensor shape: torch.Size([15, 768])
# chunk_ids length: 321
# chunk_ids length: 65
# Document tensor shape: torch.Size([2, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 402
# chunk_ids length: 146
# Document tensor shape: torch.Size([6, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 368
# chunk_ids length: 112
# Document tensor shape: torch.Size([11, 768])
# chunk_ids length: 423
# chunk_ids length: 167
# Document tensor shape: torch.Size([2, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 316
# chunk_ids length: 60
# Document tensor shape: torch.Size([4, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 385
# chunk_ids length: 129
# Document tensor shape: torch.Size([13, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 282
# chunk_ids length: 26
# Document tensor shape: torch.Size([23, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 301
# chunk_ids length: 45
# Document tensor shape: torch.Size([31, 768])
# chunk_ids length: 512
# chunk_ids length: 441
# chunk_ids length: 185
# Document tensor shape: torch.Size([3, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 409
# chunk_ids length: 153
# Document tensor shape: torch.Size([51, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 406
# chunk_ids length: 150
# Document tensor shape: torch.Size([18, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 490
# chunk_ids length: 234
# Document tensor shape: torch.Size([19, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 415
# chunk_ids length: 159
# Document tensor shape: torch.Size([22, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 467
# chunk_ids length: 211
# Document tensor shape: torch.Size([29, 768])
# chunk_ids length: 512
# chunk_ids length: 335
# chunk_ids length: 79
# Document tensor shape: torch.Size([3, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 347
# chunk_ids length: 91
# Document tensor shape: torch.Size([16, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 333
# chunk_ids length: 77
# Document tensor shape: torch.Size([6, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 506
# chunk_ids length: 250
# Document tensor shape: torch.Size([37, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 283
# chunk_ids length: 27
# Document tensor shape: torch.Size([26, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 402
# chunk_ids length: 146
# Document tensor shape: torch.Size([8, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 301
# chunk_ids length: 45
# Document tensor shape: torch.Size([9, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 337
# chunk_ids length: 81
# Document tensor shape: torch.Size([49, 768])
# chunk_ids length: 195
# Document tensor shape: torch.Size([1, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 439
# chunk_ids length: 183
# Document tensor shape: torch.Size([18, 768])
# chunk_ids length: 512
# chunk_ids length: 450
# chunk_ids length: 194
# Document tensor shape: torch.Size([3, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 340
# chunk_ids length: 84
# Document tensor shape: torch.Size([17, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 280
# chunk_ids length: 24
# Document tensor shape: torch.Size([16, 768])
# chunk_ids length: 357
# chunk_ids length: 101
# Document tensor shape: torch.Size([2, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 394
# chunk_ids length: 138
# Document tensor shape: torch.Size([10, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 451
# chunk_ids length: 195
# Document tensor shape: torch.Size([32, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 300
# chunk_ids length: 44
# Document tensor shape: torch.Size([23, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 507
# chunk_ids length: 251
# Document tensor shape: torch.Size([34, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 273
# chunk_ids length: 17
# Document tensor shape: torch.Size([20, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 424
# chunk_ids length: 168
# Document tensor shape: torch.Size([7, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 510
# chunk_ids length: 254
# Document tensor shape: torch.Size([9, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 455
# chunk_ids length: 199
# Document tensor shape: torch.Size([25, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 293
# chunk_ids length: 37
# Document tensor shape: torch.Size([16, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 395
# chunk_ids length: 139
# Document tensor shape: torch.Size([8, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 346
# chunk_ids length: 90
# Document tensor shape: torch.Size([9, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 456
# chunk_ids length: 200
# Document tensor shape: torch.Size([7, 768])
# chunk_ids length: 101
# Document tensor shape: torch.Size([1, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 511
# chunk_ids length: 255
# Document tensor shape: torch.Size([10, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 427
# chunk_ids length: 171
# Document tensor shape: torch.Size([14, 768])
# chunk_ids length: 512
# chunk_ids length: 268
# chunk_ids length: 12
# Document tensor shape: torch.Size([3, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 268
# chunk_ids length: 12
# Document tensor shape: torch.Size([11, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 420
# chunk_ids length: 164
# Document tensor shape: torch.Size([7, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 377
# chunk_ids length: 121
# Document tensor shape: torch.Size([24, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 390
# chunk_ids length: 134
# Document tensor shape: torch.Size([7, 768])
# chunk_ids length: 381
# chunk_ids length: 125
# Document tensor shape: torch.Size([2, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 312
# chunk_ids length: 56
# Document tensor shape: torch.Size([11, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 354
# chunk_ids length: 98
# Document tensor shape: torch.Size([7, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 449
# chunk_ids length: 193
# Document tensor shape: torch.Size([15, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 502
# chunk_ids length: 246
# Document tensor shape: torch.Size([92, 768])
# chunk_ids length: 512
# ...
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 357
# chunk_ids length: 101
# Document tensor shape: torch.Size([15, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 362
# chunk_ids length: 106
# Document tensor shape: torch.Size([24, 768])
# chunk_ids length: 468
# chunk_ids length: 212
# Document tensor shape: torch.Size([2, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 321
# chunk_ids length: 65
# Document tensor shape: torch.Size([9, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 446
# chunk_ids length: 190
# Document tensor shape: torch.Size([44, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 366
# chunk_ids length: 110
# Document tensor shape: torch.Size([10, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 331
# chunk_ids length: 75
# Document tensor shape: torch.Size([13, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 260
# chunk_ids length: 4
# Document tensor shape: torch.Size([11, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 394
# chunk_ids length: 138
# Document tensor shape: torch.Size([5, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 444
# chunk_ids length: 188
# Document tensor shape: torch.Size([9, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 453
# chunk_ids length: 197
# Document tensor shape: torch.Size([4, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 487
# chunk_ids length: 231
# Document tensor shape: torch.Size([4, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 292
# chunk_ids length: 36
# Document tensor shape: torch.Size([14, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 320
# chunk_ids length: 64
# Document tensor shape: torch.Size([12, 768])
# chunk_ids length: 512
# chunk_ids length: 462
# chunk_ids length: 206
# Document tensor shape: torch.Size([3, 768])
# chunk_ids length: 437
# chunk_ids length: 181
# Document tensor shape: torch.Size([2, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 437
# chunk_ids length: 181
# Document tensor shape: torch.Size([9, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 280
# chunk_ids length: 24
# Document tensor shape: torch.Size([22, 768])
# chunk_ids length: 346
# chunk_ids length: 90
# Document tensor shape: torch.Size([2, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 416
# chunk_ids length: 160
# Document tensor shape: torch.Size([35, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 480
# chunk_ids length: 224
# Document tensor shape: torch.Size([16, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 464
# chunk_ids length: 208
# Document tensor shape: torch.Size([14, 768])
# chunk_ids length: 500
# chunk_ids length: 244
# Document tensor shape: torch.Size([2, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 481
# chunk_ids length: 225
# Document tensor shape: torch.Size([15, 768])
# chunk_ids length: 512
# chunk_ids length: 352
# chunk_ids length: 96
# Document tensor shape: torch.Size([3, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 455
# chunk_ids length: 199
# Document tensor shape: torch.Size([19, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 407
# chunk_ids length: 151
# Document tensor shape: torch.Size([35, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 282
# chunk_ids length: 26
# Document tensor shape: torch.Size([17, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 314
# chunk_ids length: 58
# Document tensor shape: torch.Size([14, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 312
# chunk_ids length: 56
# Document tensor shape: torch.Size([20, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 432
# chunk_ids length: 176
# Document tensor shape: torch.Size([5, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 340
# chunk_ids length: 84
# Document tensor shape: torch.Size([11, 768])
# chunk_ids length: 512
# chunk_ids length: 472
# chunk_ids length: 216
# Document tensor shape: torch.Size([3, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 429
# chunk_ids length: 173
# Document tensor shape: torch.Size([6, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 266
# chunk_ids length: 10
# Document tensor shape: torch.Size([30, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 441
# chunk_ids length: 185
# Document tensor shape: torch.Size([19, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 501
# chunk_ids length: 245
# Document tensor shape: torch.Size([46, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 334
# chunk_ids length: 78
# Document tensor shape: torch.Size([16, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 340
# chunk_ids length: 84
# Document tensor shape: torch.Size([15, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 290
# chunk_ids length: 34
# Document tensor shape: torch.Size([15, 768])
# chunk_ids length: 81
# Document tensor shape: torch.Size([1, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 456
# chunk_ids length: 200
# Document tensor shape: torch.Size([6, 768])
# chunk_ids length: 249
# Document tensor shape: torch.Size([1, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 368
# chunk_ids length: 112
# Document tensor shape: torch.Size([26, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 449
# chunk_ids length: 193
# Document tensor shape: torch.Size([16, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 511
# chunk_ids length: 255
# Document tensor shape: torch.Size([8, 768])
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 512
# chunk_ids length: 285
# chunk_ids length: 29
# Document tensor shape: torch.Size([11, 768])
# Saved dev data: data_dev.pt
